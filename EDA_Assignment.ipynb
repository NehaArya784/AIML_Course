# %%
#import neccesarry libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
#read the csv file

data=pd.read_csv("tested.csv")

# %%
data  #print the dataset
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
#print first 20 rows of the dataset

data.head(20)
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                                    Kelly, Mr. James    male  34.5      0
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# ...

# %%
#print last 5 rows of the dataset

data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
#check the data types and null values in the dataset

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
#check the summary of the dataset

data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
#Check random rows of the dataset

data.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 309         1201         1       3
# 34           926         0       1
# 189         1081         0       2
# 335         1227         0       1
# 217         1109         0       1
# 355         1247         0       1
# 263         1155         1       3
# 161         1053         0       3
# 267         1159         0       3
# 304         1196         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 309  Hansen, Mrs. Claus Peter (Jennie L Howard)  female  45.0      1      0
# 34                     Mock, Mr. Philipp Edmund    male  30.0      1      0
# 189                             Veal, Mr. James    male  40.0      0      0
# 335                    Maguire, Mr. John Edward    male  30.0      0      0
# 217                    Wick, Mr. George Dennick    male  57.0      1      1
# 355                    Julian, Mr. Henry Forbes    male  50.0      0      0
# ...

# %%
#to get first 15 rows of the dataset
#iloc is used to access a group of rows and columns by labels or a boolean array
data.iloc[1:15]
# Out:
#     PassengerId  Survived  Pclass  \
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1                    Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                           Myles, Mr. Thomas Francis    male  62.0      0
# 3                                    Wirz, Mr. Albert    male  27.0      0
# 4        Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# ...

# %%
#For checking the number of  missing values in each column in the dataset

data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Checking missing values for a particular column

data['Age'].isnull().sum()
# Out:
# np.int64(86)

# %%
#Check missing values for multiple columns

data[['Age','Cabin','Name']].isnull().sum()
# Out:
# Age       86
# Cabin    327
# Name       0
# dtype: int64

# %%
#Check the duplicate rows in the dataset

data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Handle These Errors Or Anomalies

# %%
#Drop rows with any missing values

data_listwise_deletion=data.dropna()

#Drop rows with missing values in 'Cabin' columns

data_pairwise_deletion=data.dropna(subset=['Age'])

#Checking remaining missing values

print(data_pairwise_deletion.isnull().sum())
print(data_listwise_deletion.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          245
# Embarked         0
# dtype: int64
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Drop rows with any missing values

data_listwise_deletion=data.dropna()

#Drop rows with missing values in 'Cabin' columns

data_pairwise_deletion=data.dropna(subset=['Cabin'])

#Checking remaining missing values

print(data_pairwise_deletion.isnull().sum())
print(data_listwise_deletion.isnull().sum())
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            4
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
#Drop rows with any missing values

data_listwise_deletion=data.dropna()

#Drop rows with missing values in 'Cabin' columns

data_pairwise_deletion=data.dropna(subset=['Fare'])

#Checking remaining missing values

print(data_pairwise_deletion.isnull().sum())
print(data_listwise_deletion.isnull().sum())
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          326
# Embarked         0
# dtype: int64
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# ## IMPUTATION-IMPUTE-FILLING THE VALUES

# %%
#Check the null values in each column

data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#Print the data

data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ### Mean Imputation in 'Age' Column

# %%
#Calculate the mean of the 'Age' column

mean_Age=data['Age'].mean()
mean_Age
# Out:
# np.float64(30.272590361445783)

# %%
#Create a copy of the data to avoid modifying the original dataset

data1=data.copy()

# %%
#Fill missing values in 'Age' column with the mean value

data1['Age'].fillna(mean_Age)
# Out:
# 0      34.50000
# 1      47.00000
# 2      62.00000
# 3      27.00000
# 4      22.00000
#          ...
# 413    30.27259
# 414    39.00000
# 415    38.50000
# 416    30.27259
# 417    30.27259
# Name: Age, Length: 418, dtype: float64

# %%
#For removing the decimal part from the data use floor division

mean_Age//1
# Out:
# np.float64(30.0)

# %%
#Round the mean value to a 0 places

round(mean_Age)
# Out:
# 30

# %%
#Fill missing values in 'Age' column with the round mean value

data1['Age']=data1['Age'].fillna(round(mean_Age),inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4136\2060317330.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['Age']=data1['Age'].fillna(round(mean_Age),inplace=True)

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  None      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  None      1      0
# 2                       Myles, Mr. Thomas Francis    male  None      0      0
# 3                                Wirz, Mr. Albert    male  None      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  None      1      1
# ...

# %% [markdown]
# ### Median Imputation in 'Age' Column

# %%
#Calculate the median of the 'Cabin' column

median_Age=data['Age'].median()
median_Age
# Out:
# np.float64(27.0)

# %% [markdown]
# ### Mode Imputation in 'Age' Column

# %%
#Calculate the mode for the 'Age' column

mode_Age=data['Age'].mode()[0]
mode_Age
# Out:
# np.float64(21.0)

# %% [markdown]
# ### Mean Imputation in 'Fare Column'

# %%
#Calculate the mean of the 'fare' Column

mean_Fare=data['Fare'].mean()
mean_Fare
# Out:
# np.float64(35.627188489208635)

# %%
#Create a copy of the data to avoid modifying the original dataset

data2=data.copy()

# %%
#Fill missing values in 'Age' column with the mean value

data2['Fare'].fillna(mean_Fare)
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
#For removing the decimal part from the data use floor division

mean_Fare//1
# Out:
# np.float64(35.0)

# %%
#Round the mean value to a 0 places

round(mean_Fare)
# Out:
# 36

# %%
#Fill missing values in 'Age' column with the round mean value

data2['Fare']=data2['Fare'].fillna(round(mean_Fare),inplace=True)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_4136\4035401221.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data2['Fare']=data2['Fare'].fillna(round(mean_Fare),inplace=True)

# %%
data2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ### Median Imputation in 'Fare' Column

# %%
#Calculate the median of the 'Cabin' column

median_Fare=data['Fare'].median()
median_Fare
# Out:
# np.float64(14.4542)

# %% [markdown]
# ### Mode Imputation in 'Fare' Column

# %%
mode_Fare=data['Fare'].mode()
mode_Fare
# Out:
# 0    7.75
# Name: Fare, dtype: float64

# %% [markdown]
# ## Data Visualization

# %%
data1
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  None      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  None      1      0
# 2                       Myles, Mr. Thomas Francis    male  None      0      0
# 3                                Wirz, Mr. Albert    male  None      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  None      1      1
# ...

# %%
#Import the necessary libraries

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Bar Plots

# %%
data['Pclass'].value_counts().plot(kind='bar',color='red')
plt.xlabel('Passenger Class')
plt.ylabel('Count')
plt.title('Number of Passengers by Class')
plt.show()

# %% [markdown]
# ### Scatter Plots

# %%
plt.scatter(data['Age'], data['Fare'], alpha=0.7,color='black')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Scatter Plot of Age vs Fare')
plt.show()

# %% [markdown]
# ### Line Plot

# %%
plt.plot(data['Age'][:50], label='Age')
plt.plot(data['Fare'][:50], label='Fare')
plt.xlabel('Passenger Index')
plt.ylabel('Value')
plt.title('Line Plot of Age and Fare')
plt.legend()
plt.show()

# %% [markdown]
# ### Histogram Plot

# %%
plt.hist(data['Age'].dropna(), bins=30, color='skyblue', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()

# %%
plt.bar(data1,Fare,color='red',width=0.8)
